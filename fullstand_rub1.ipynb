# %%
from main import main, context_length, prediction_length
from vierlinden.data.loader import VierlindenDataProcessor
from vierlinden.config import model_output_path

target = "Füllstand_RüB_1"
model_filepath = model_output_path + "/NHiTS"  + target + "_model.pt"

dp = VierlindenDataProcessor()
df = dp.load_processed_data()
df = dp.prepare_for_target(df, target)
dp.plot_target_col(target)
# Out:
# INFO:vierlinden.data.loader:Data loaded successfully from /storage/projects/RIWWER/data/Vierlinden
# INFO:vierlinden.data.loader:Sensor and target data merged successfully.
# INFO:vierlinden.data.loader:NaN values processed successfully.
# INFO:vierlinden.data.loader:Data loaded and processed successfully.

# %% [markdown]
# ## Training

# %%
training_wrapper, test_df = main(target)
training_wrapper.save_trained_model(model_filepath)

print(training_wrapper.metrics_callback.metrics["train_loss"])
print(training_wrapper.metrics_callback.metrics["val_loss"])

training_wrapper.plot_training_result()
# Out:
# INFO:vierlinden.data.loader:Data loaded successfully from /storage/projects/RIWWER/data/Vierlinden
# INFO:vierlinden.data.loader:Sensor and target data merged successfully.
# INFO:vierlinden.data.loader:NaN values processed successfully.
# INFO:vierlinden.data.loader:Data loaded and processed successfully.
# INFO:vierlinden.model.model:Training and validation data and data loaders created successfully.
# Global seed set to 42
# You are using a CUDA device ('NVIDIA A100 80GB PCIe') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Finding best initial lr:  93%|█████████▎| 93/100 [00:02<00:00, 67.39it/s]`Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:03<00:00, 32.48it/s]
# INFO:vierlinden.model.model:Start setting up trainer and network.
# Global seed set to 42
# INFO:vierlinden.model.model:Setup succesful. Starting training procedure.
# Optimal learning rate for Füllstand_RüB_1: 0.0003981071705534973
#   | Name            | Type           | Params
# ---------------------------------------------------
# 0 | loss            | MASE           | 0
# 1 | logging_metrics | ModuleList     | 0
# 2 | embeddings      | MultiEmbedding | 0
# 3 | model           | NHiTS          | 919 K
# ---------------------------------------------------
# 919 K     Trainable params
# 0         Non-trainable params
# 919 K     Total params
# 3.679     Total estimated model params size (MB)
# Epoch 0: 100%|██████████| 193/193 [00:24<00:00,  8.03it/s, v_num=0, train_loss_step=6.110, val_loss=2.100, train_loss_epoch=3.940]
# Metric val_loss improved. New best score: 2.099
# Epoch 1: 100%|██████████| 193/193 [00:23<00:00,  8.13it/s, v_num=0, train_loss_step=5.950, val_loss=2.060, train_loss_epoch=3.690]
# Metric val_loss improved by 0.044 >= min_delta = 0.0001. New best score: 2.055
# Epoch 2: 100%|██████████| 193/193 [00:25<00:00,  7.68it/s, v_num=0, train_loss_step=2.690, val_loss=2.040, train_loss_epoch=3.620]
# Metric val_loss improved by 0.018 >= min_delta = 0.0001. New best score: 2.037
# Epoch 3: 100%|██████████| 193/193 [00:24<00:00,  7.78it/s, v_num=0, train_loss_step=2.440, val_loss=2.020, train_loss_epoch=3.570]
# Metric val_loss improved by 0.022 >= min_delta = 0.0001. New best score: 2.015
# Epoch 4:   0%|          | 0/193 [00:00<?, ?it/s, v_num=0, train_loss_step=2.440, val_loss=2.020, train_loss_epoch=3.570]
# Swapping scheduler `ReduceLROnPlateau` for `SWALR`
# Epoch 4: 100%|██████████| 193/193 [00:25<00:00,  7.63it/s, v_num=0, train_loss_step=4.510, val_loss=2.010, train_loss_epoch=3.540]
# Metric val_loss improved by 0.008 >= min_delta = 0.0001. New best score: 2.007
# Epoch 5: 100%|██████████| 193/193 [00:23<00:00,  8.07it/s, v_num=0, train_loss_step=2.500, val_loss=1.970, train_loss_epoch=3.500]
# Metric val_loss improved by 0.033 >= min_delta = 0.0001. New best score: 1.974
# Epoch 9: 100%|██████████| 193/193 [00:27<00:00,  7.04it/s, v_num=0, train_loss_step=2.320, val_loss=1.940, train_loss_epoch=3.420]
# Metric val_loss improved by 0.031 >= min_delta = 0.0001. New best score: 1.943
# Epoch 12: 100%|██████████| 193/193 [00:28<00:00,  6.71it/s, v_num=0, train_loss_step=4.180, val_loss=1.940, train_loss_epoch=3.380]
# Metric val_loss improved by 0.004 >= min_delta = 0.0001. New best score: 1.939
# Epoch 13: 100%|██████████| 193/193 [00:24<00:00,  7.73it/s, v_num=0, train_loss_step=2.930, val_loss=1.930, train_loss_epoch=3.360]
# Metric val_loss improved by 0.012 >= min_delta = 0.0001. New best score: 1.926
# Epoch 16: 100%|██████████| 193/193 [00:24<00:00,  7.72it/s, v_num=0, train_loss_step=2.510, val_loss=1.930, train_loss_epoch=3.330]
# Metric val_loss improved by 0.000 >= min_delta = 0.0001. New best score: 1.926
# Epoch 17: 100%|██████████| 193/193 [00:24<00:00,  7.75it/s, v_num=0, train_loss_step=4.600, val_loss=1.910, train_loss_epoch=3.320]
# Metric val_loss improved by 0.013 >= min_delta = 0.0001. New best score: 1.913
# Epoch 18: 100%|██████████| 193/193 [00:25<00:00,  7.61it/s, v_num=0, train_loss_step=3.050, val_loss=1.910, train_loss_epoch=3.320]
# Metric val_loss improved by 0.002 >= min_delta = 0.0001. New best score: 1.911
# Epoch 24: 100%|██████████| 193/193 [00:32<00:00,  5.94it/s, v_num=0, train_loss_step=4.680, val_loss=1.910, train_loss_epoch=3.290]
# Metric val_loss improved by 0.003 >= min_delta = 0.0001. New best score: 1.908
# Epoch 27: 100%|██████████| 193/193 [00:26<00:00,  7.26it/s, v_num=0, train_loss_step=2.550, val_loss=1.910, train_loss_epoch=3.280]
# Metric val_loss improved by 0.002 >= min_delta = 0.0001. New best score: 1.906
# Epoch 30: 100%|██████████| 193/193 [00:35<00:00,  5.39it/s, v_num=0, train_loss_step=2.400, val_loss=1.910, train_loss_epoch=3.270]
# Metric val_loss improved by 0.000 >= min_delta = 0.0001. New best score: 1.905
# Epoch 33: 100%|██████████| 193/193 [00:28<00:00,  6.79it/s, v_num=0, train_loss_step=4.080, val_loss=1.900, train_loss_epoch=3.270]
# Metric val_loss improved by 0.000 >= min_delta = 0.0001. New best score: 1.905
# Epoch 36: 100%|██████████| 193/193 [00:29<00:00,  6.65it/s, v_num=0, train_loss_step=3.960, val_loss=1.900, train_loss_epoch=3.250]
# Metric val_loss improved by 0.000 >= min_delta = 0.0001. New best score: 1.904
# Epoch 37: 100%|██████████| 193/193 [00:39<00:00,  4.90it/s, v_num=0, train_loss_step=2.900, val_loss=1.900, train_loss_epoch=3.260]
# Metric val_loss improved by 0.003 >= min_delta = 0.0001. New best score: 1.901
# Epoch 47: 100%|██████████| 193/193 [00:30<00:00,  6.34it/s, v_num=0, train_loss_step=4.130, val_loss=1.910, train_loss_epoch=3.230]
# Monitored metric val_loss did not improve in the last 10 records. Best score: 1.901. Signaling Trainer to stop.
# Epoch 47: 100%|██████████| 193/193 [00:30<00:00,  6.28it/s, v_num=0, train_loss_step=4.130, val_loss=1.910, train_loss_epoch=3.230]
# INFO:vierlinden.model.model:Training procedure completed.
# INFO:vierlinden.model.model:Cleaning up logging files.
# INFO:vierlinden.model.model:Logging files cleaned up.
# [3.940904378890991, 3.6864168643951416, 3.618856430053711, 3.5746374130249023, 3.5401716232299805, 3.501549243927002, 3.476048707962036, 3.4544777870178223, 3.4424867630004883, 3.4178314208984375, 3.39851713180542, 3.3909833431243896, 3.3760857582092285, 3.3649628162384033, 3.358053684234619, 3.3444113731384277, 3.3251874446868896, 3.322087287902832, 3.323199510574341, 3.297083616256714, 3.313147783279419, 3.308844566345215, 3.2983574867248535, 3.294677734375, 3.2892844676971436, 3.284803867340088, 3.2853784561157227, 3.276250123977661, 3.2670607566833496, 3.2758994102478027, 3.26961088180542, 3.2581193447113037, 3.261606216430664, 3.2661685943603516, 3.25885272026062, 3.2595508098602295, 3.254901170730591, 3.2576558589935303, 3.245279312133789, 3.24546217918396, 3.2418415546417236, 3.2481753826141357, 3.232574224472046, 3.240964651107788, 3.238903522491455, 3.239671468734741, 3.233006238937378, 3.2333831787109375]
# [2.099076271057129, 2.0551772117614746, 2.0374600887298584, 2.015228509902954, 2.007312297821045, 1.9740554094314575, 1.9785590171813965, 1.9807400703430176, 1.9839013814926147, 1.9430365562438965, 1.95415461063385, 1.944164514541626, 1.9388372898101807, 1.9263677597045898, 1.9381365776062012, 1.9398554563522339, 1.9258776903152466, 1.912638545036316, 1.9109208583831787, 1.9227180480957031, 1.9146366119384766, 1.9385982751846313, 1.92240571975708, 1.9158718585968018, 1.9075191020965576, 1.9126158952713013, 1.909346580505371, 1.9055920839309692, 1.9117140769958496, 1.92079758644104, 1.9051871299743652, 1.9148021936416626, 1.9246140718460083, 1.904887318611145, 1.911371111869812, 1.9131147861480713, 1.9044181108474731, 1.9013899564743042, 1.9079957008361816, 1.9145598411560059, 1.9155921936035156, 1.9094252586364746, 1.9023298025131226, 1.9093443155288696, 1.9110404253005981, 1.9149733781814575, 1.9231653213500977, 1.909386396408081]

# %% [markdown]
# ## Testing

# %%
from vierlinden.model.model import NHiTSTrainingWrapper, NHiTSPredictionWrapper

model = NHiTSTrainingWrapper.load_trained_model(model_filepath)
prediction_wrapper = NHiTSPredictionWrapper(model, context_length=context_length, prediction_length=prediction_length, target_col=target)

if test_df is None:
    df = dp.load_processed_data()
    df = dp.prepare_for_target(df, target)
    training_df, test_df = dp.split_data(df)
    
prediction_df = prediction_wrapper.predict(test_df)
mase = prediction_wrapper.calculate_mase_loss()

print("MASE = ", mase)
# Out:
# /storage/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:442: PossibleUserWarning: The dataloader, predict_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 96 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# MASE =  0.9965723491682934

# %%
prediction_df.iloc[110:120]
# Out:
#                Datetime  Schieber Position_pval  Oberwasser_pval  \
# 110 2021-11-30 10:00:00                   100.0        18.578947
# 111 2021-11-30 11:00:00                   100.0        18.518072
# 112 2021-11-30 12:00:00                   100.0        20.239437
# 113 2021-11-30 13:00:00                   100.0        34.907216
# 114 2021-11-30 14:00:00                   100.0        39.345679
# 115 2021-11-30 15:00:00                   100.0        36.766234
# 116 2021-11-30 16:00:00                   100.0        39.385542
# 117 2021-11-30 17:00:00                   100.0        27.098765
# 118 2021-11-30 18:00:00                   100.0        22.397436
# 119 2021-11-30 19:00:00                   100.0        28.647887
#
#      Unterwasser_pval  Durchflumenge_pval  Berechnete Durchflussmenge_pval  \
# 110         12.140625           41.424528                        39.932039
# 111         12.318841           41.348624                        38.694444
# 112         13.214286           46.018868                        46.231481
# 113         22.023256          130.716667                       109.172414
# 114         24.333333          157.921053                       129.577982
# 115         22.929577          142.059829                       115.964286
# 116         24.225000          158.060870                       131.165138
# 117         17.081081           84.297297                        73.449541
# 118         14.292683           57.223214                        54.355140
# 119         17.860759           91.504505                        81.609091
#
#      Fllstand SWS_pval  Fllstand RWS_pval  Strom P1_pval  Strom P2_pval  ...  \
# 110         102.900000          35.000000       7.000000       0.000000  ...
# 111          75.859649          35.000000       5.842105       0.000000  ...
# 112          75.633333          35.000000       5.066667       0.000000  ...
# 113         106.850000          35.000000       4.616667      16.666667  ...
# 114         112.516667          35.416667       3.716667      25.150000  ...
# 115         118.483333          36.000000       4.000000      16.633333  ...
# 116         117.816667          36.500000       3.933333      22.133333  ...
# 117         134.150000          37.000000       5.750000       1.833333  ...
# 118         134.183333          37.000000       5.800000       3.783333  ...
# 119         129.883333          37.000000       5.200000       5.466667  ...
#
#      Fllstand Pumpensumpf_pval  Strom Pumpe 1_pval  Strom Pumpe 2_pval  \
# 110                  47.066667            1.064516            0.677419
# 111                  48.367521            0.580645            0.000000
# 112                  47.400000            0.580645            1.000000
# 113                  68.120879            3.540984            5.078125
# 114                  86.897436            5.492308            5.000000
# 115                  97.038961            5.343284            5.000000
# 116                 103.797101            5.380282            5.000000
# 117                 106.387097            5.109375            5.000000
# 118                 104.507246            5.132353            5.000000
# 119                 107.149254            5.032258            5.000000
#
#      Fllstand Pumpensumpf_pval1  Strom Pumpe 1_pval1  Strom Pumpe 2_pval1  \
# 110                   91.021739             3.548387                  0.0
# 111                   91.051948             0.000000                  0.0
# 112                   89.252632             3.709677                  0.0
# 113                  109.024096             9.016393                  0.0
# 114                  126.337079            10.000000                  0.0
# 115                  143.558824            10.000000                  0.0
# 116                  153.394737            10.000000                  0.0
# 117                  150.426966            10.000000                  0.0
# 118                  111.203883            10.000000                  0.0
# 119                   89.215909             5.645161                  0.0
#
#      Strom Pumpe 3_pval  Niederschlag  Füllstand_RüB_1  \
# 110                 1.0      0.900000             1.11
# 111                 1.0      0.885366             1.11
# 112                 1.0      1.237500             1.11
# 113                 1.0      2.779592             1.32
# 114                 1.0      2.937391             3.75
# 115                 1.0      2.153571             5.07
# 116                 1.0      2.651282             5.55
# 117                 1.0      0.975000             5.64
# 118                 1.0      1.688000             5.62
# 119                 1.0      1.187755             5.63
#
#                                     Predicted Forecast
# 110  [1.1100000143051147, 1.1100000143051147, 1.110...
# 111  [1.1100000143051147, 1.1100000143051147, 1.110...
# 112  [1.1100000143051147, 1.1100000143051147, 1.110...
# 113  [1.1100000143051147, 1.1100000143051147, 1.110...
# 114  [1.3276560306549072, 1.3261433839797974, 1.326...
# 115  [3.8442959785461426, 3.827651262283325, 3.8262...
# 116  [5.1300506591796875, 5.118638515472412, 5.1060...
# 117  [5.571833610534668, 5.558758735656738, 5.53450...
# 118  [5.654262542724609, 5.6413679122924805, 5.6193...
# 119  [5.633861064910889, 5.635246276855469, 5.61275...
#
# [10 rows x 24 columns]

# %%
prediction_wrapper.plot_forecast_for_all(forecast_step_ahead=1, plot_forecast_distribution=True)

# %%
prediction_wrapper.plot_forecast_per_time_idx(115)
prediction_wrapper.plot_forecast_per_time_idx(120)
